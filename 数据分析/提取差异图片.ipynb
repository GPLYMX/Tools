# %%
import os
import json

# %%
with open('st2_total_detail(20220506)_sm_noval_last.json', 'r', encoding='utf-8') as f:
    json_data1 = json.load(f)
    lst1 = list(json_data1.keys())
with open('second_total_detail(20220808)_sm.json', 'r', encoding='utf-8') as f:
    json_data2 = json.load(f)
    lst2 = list(json_data2.keys())

# %%
lst = []
for i in lst2:
    if i not in lst1:
        lst.append(i)

# %%
lst
# Out:
# ['20220508090406-1',
#  '20220509081413-1',
#  '20220509093029-1',
#  '20220509153248-1',
#  '20220510082753-1',
#  '20220510105355-1',
#  '20220510110651-1',
#  '20220510124949-1',
#  '20220510145856-1',
#  '20220510150025-1',
#  '20220510184816-1',
#  '20220511090807-1',
#  '20220511091101-1',
#  '20220511091312-1',
#  '20220511091450-1',
#  '20220511110244-1',
#  '20220511113332-1',
#  '20220511114701-1',
#  '20220511145559-1',
#  '20220511150148-1',
#  '20220511154017-1',
#  '20220511160107-1',
#  '20220511161402-1',
#  '20220511165155-1',
#  '20220511171140-1',
#  '20220511180748-1',
#  '20220512140559-1',
#  '20220512144442-1',
#  '20220512150207-1',
#  '20220512154808-1',
#  '20220512163610-1',
#  '20220513081432-1',
#  '20220513085540-1',
#  '20220513101249-1',
#  '20220513104250-1',
#  '20220513112126-1',
#  '20220513113944-1',
#  '20220513120614-1',
#  '20220513142124-1',
#  '20220513142443-1',
#  '20220514100901-1',
#  '20220514102841-1',
#  '20220516105826-1',
# ...

# %%
label = list(json_data2[lst[1]]['苔色'].values())

# %%
label = [3, 5, 2]

# %%
label.index(max(label))
# Out:
# 1

# %%
a = os.listdir(r'D:\MyCodes\pythonProject\datas\data2all\seg-crop')

# %%
len(a)
# Out:
# 2094

# %%
a = list((2, 3, 4, 8))

# %%
a
# Out:
# [2, 3, 4, 8]

# %%
*list((2, (3, 4), 8))
# Out:
#   Input In [9]
#     *list((2, (3, 4), 8))
#     ^
# SyntaxError: can't use starred expression here
