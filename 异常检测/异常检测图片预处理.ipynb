# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
root = r'D:\MyCodes\pythonProject\coated_tongue_color\datas\data1&data2\category\2\27.png'

# %%
img = cv.imread(root)

# %%
plt.imshow(img[:,:,::-1])

# %%
blur = cv.GaussianBlur(img[100:200, 100:200, :], (9, 9,), 50)

# %%
plt.imshow(blur[:,:,::-1])
