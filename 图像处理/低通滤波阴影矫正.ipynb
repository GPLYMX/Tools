# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
root = r'D:\MyCodes\pythonProject\coated_tongue_color\datas\data3\category\0\50.png'

# %%
img = cv.imread(root)

# %%
plt.imshow(img[:,:,::-1])

# %%
img_blur=cv.GaussianBlur(img,(51,51),9)

# %%
plt.imshow(img_blur[:,:,::-1])

# %%
img1DivImg2 = cv.subtract(img, img_blur)

# %%
plt.imshow(220 * img1DivImg2[:,:,::-1])

# %% [markdown]
# a = np.array([1, 2])

# %%
b = 10 * a

# %%
b
# Out:
# array([10, 20])
