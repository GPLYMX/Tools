# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = cv.imread(r'D:\MyCodes\pythonProject\coated_tongue_color\datas\data2\category\1\20220510112740-1.png')

# %%
plt.imshow(img[:,:,::-1])

# %%
HSV_img = cv.cvtColor(img,cv.COLOR_BGR2HSV)

# %%
plt.imshow(HSV_img[:,:,::-1])

# %%
img[200, 300]
# Out:
# array([123, 151, 162], dtype=uint8)

# %%
HSV_img[200, 300]
# Out:
# array([ 22,  61, 162], dtype=uint8)

# %%
img[200, 100]
# Out:
# array([167, 170, 198], dtype=uint8)

# %%
img = Image.open(r'D:\MyCodes\pythonProject\coated_tongue_color\datas\data2\category\1\20220510112740-1.png').convert('RGB')

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=576x480 at 0x1ECB2EBB6D0>
