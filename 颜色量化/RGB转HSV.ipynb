# %%
import os

import cv2 as cv
from tqdm import tqdm
from matplotlib import pyplot as plt

# %%
root = r'D:\MyCodes\pythonProject\coated_tongue_color\datas\data_coated\category'
for filelst in tqdm(os.listdir(root)):
    for img in tqdm(os.listdir(os.path.join(root, filelst))):
        if img[-5] != 'g':
            print(img)
            
            new_name = img[:-4] + 'h' +'.png'
            h_img = cv.cvtColor(os.path.join(root, filelst, img), cv.COLOR_BGR2HSV)
            cv.imwrite(os.path.join(root, filelst, new_name), h_img[:,:,0])
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████| 2344/2344 [00:00<00:00, 65359.98it/s]
# 20220508081924-1.png
# 20220508083039-1.png
# 20220508083452-1.png
# 20220508084834-1.png
# 20220508090406-1.png
# 20220508092230-1.png
# 20220508093841-1.png
# 20220508094045-1.png
# 20220508102258-1.png
# 20220508103538-1.png
# 20220508130943-1.png
# 20220508162203-1.png
# 20220509081413-1.png
# 20220509083257-1.png
# 20220509090338-1.png
# 20220509090829-1.png
# 20220509092037-1.png
# 20220509093008-1.png
# 20220509093029-1.png
# 20220509094537-1.png
# 20220509094624-1.png
# 20220509094753-1.png
# 20220509102112-1.png
# 20220509103938-1.png
# 20220509110016-1.png
# 20220509111225-1.png
# 20220509111313-1.png
# 20220509111820-1.png
# 20220509113835-1.png
# 20220509114519-1.png
# 20220509114911-1.png
# 20220509120506-1.png
# 20220509122515-1.png
# 20220509143504-1.png
# 20220509145952-1.png
# 20220509153248-1.png
# 20220509154934-1.png
# 20220509160417-1.png
# ...

# %%
root = r'D:\MyCodes\pythonProject\coated_tongue_color\datas\data_coated\category\0\20220513142124-1.png'
img = cv.imread(root)
h_img = cv.cvtColor(img, cv.COLOR_BGR2HSV)
h_img[:,:,0].shape
plt.imshow(h_img[:,:,0])

# %%
image = cv2.imread('fruits.jpg')
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2.imshow('Input', image)
cv2.imshow('Result', hsv)
cv2.waitKey(0)
